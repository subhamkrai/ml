# %%
import  matplotlib.pyplot  as  plt

x=[2,8,7,5]
x1=[4,9,7,3]
y=[3,5,1,9]
y1=[2,11,5,8]

plt.title("Hello world this is normal maths graph")
plt.xlabel("Distance")
plt.ylabel("Time")
#plt.plot(x,y,color='g',marker='*',label="danger")
plt.plot(x1,y1,color='y',label="safe")
plt.bar(x,y,label="money")
plt.bar(x1,y1,label="Time")
plt.grid(True,color='r')
plt.legend()
plt.show()
